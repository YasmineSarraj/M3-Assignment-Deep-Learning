# %% [markdown]
# <a href="https://colab.research.google.com/github/YasmineSarraj/M3-Assignments-Deep-Learning/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Mar 13 17:18:10 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    30W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install gradio -q

# %%
# !pip uninstall whisper
# Out:
# WARNING: Skipping whisper as it is not installed.

# %%
# !pip install openai-whisper==20230117
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openai-whisper==20230117 in /usr/local/lib/python3.9/dist-packages (20230117)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230117) (1.13.1+cu116)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230117) (9.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230117) (1.22.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230117) (4.65.0)
# Requirement already satisfied: transformers>=4.19.0 in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230117) (4.26.1)
# Requirement already satisfied: ffmpeg-python==0.2.0 in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230117) (0.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from ffmpeg-python==0.2.0->openai-whisper==20230117) (0.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.19.0->openai-whisper==20230117) (2022.6.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.19.0->openai-whisper==20230117) (0.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers>=4.19.0->openai-whisper==20230117) (3.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.19.0->openai-whisper==20230117) (23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.19.0->openai-whisper==20230117) (0.13.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.19.0->openai-whisper==20230117) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers>=4.19.0->openai-whisper==20230117) (2.28.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->openai-whisper==20230117) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.19.0->openai-whisper==20230117) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.19.0->openai-whisper==20230117) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.19.0->openai-whisper==20230117) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers>=4.19.0->openai-whisper==20230117) (1.26.14)

# %%
import whisper

# %%
model = whisper.load_model("medium")

# %%
url = 'https://podcasts.google.com/feed/aHR0cHM6Ly9mZWVkcy5mZWVkYnVybmVyLmNvbS9PbG9naWVz/episode/MTUwNTYzZGItMWI1My00YzY2LWI5MjAtNDRiMzBhMTkzOTg0?sa=X&ved=0CAUQkfYCahcKEwiwjPT-sdn9AhUAAAAAHQAAAAAQCg'

# %%
import requests

# %%
content = requests.get(url)

# %%
from bs4 import BeautifulSoup
import re

# %%
soup = BeautifulSoup(content.text)

# %%
podcast_url = re.findall("(?P<url>\;https?://[^\s]+)", content.text)[0].split(';')[1]

# %%
podcast_url
# Out:
# 'https://pdst.fm/e/stitcher.simplecastaudio.com/89060b63-e603-4297-b6e8-5a654e50244e/episodes/4b27f11f-0f66-4137-b607-314adfecda33/audio/128/default.mp3?aid=rss_feed&amp'

# %%
# !wget -O podcast.mp3 {podcast_url}
# Out:
# /bin/bash: amp: command not found
# --2023-03-13 17:19:00--  https://pdst.fm/e/stitcher.simplecastaudio.com/89060b63-e603-4297-b6e8-5a654e50244e/episodes/4b27f11f-0f66-4137-b607-314adfecda33/audio/128/default.mp3?aid=rss_feed
# Resolving pdst.fm (pdst.fm)... 216.239.34.21, 216.239.32.21, 216.239.38.21, ...
# Connecting to pdst.fm (pdst.fm)|216.239.34.21|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://stitcher.simplecastaudio.com/89060b63-e603-4297-b6e8-5a654e50244e/episodes/4b27f11f-0f66-4137-b607-314adfecda33/audio/128/default.mp3?aid=rss_feed [following]
# --2023-03-13 17:19:00--  https://stitcher.simplecastaudio.com/89060b63-e603-4297-b6e8-5a654e50244e/episodes/4b27f11f-0f66-4137-b607-314adfecda33/audio/128/default.mp3?aid=rss_feed
# Resolving stitcher.simplecastaudio.com (stitcher.simplecastaudio.com)... 108.156.83.122, 108.156.83.31, 108.156.83.96, ...
# Connecting to stitcher.simplecastaudio.com (stitcher.simplecastaudio.com)|108.156.83.122|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://stitcher.simplecastaudio.com/89060b63-e603-4297-b6e8-5a654e50244e/episodes/4b27f11f-0f66-4137-b607-314adfecda33/audio/128/default.mp3/default.mp3_ywr3ahjkcgo_fd7224e13d171850f36805aec8efb435_21652168.mp3?aid=rss_feed&hash_redirect=1&x-total-bytes=21652168&x-ais-classified=unclassified&listeningSessionID=0CD_382_71__38c871ffc98aec765e17486bf1432ffad1ed0f23 [following]
# --2023-03-13 17:19:01--  https://stitcher.simplecastaudio.com/89060b63-e603-4297-b6e8-5a654e50244e/episodes/4b27f11f-0f66-4137-b607-314adfecda33/audio/128/default.mp3/default.mp3_ywr3ahjkcgo_fd7224e13d171850f36805aec8efb435_21652168.mp3?aid=rss_feed&hash_redirect=1&x-total-bytes=21652168&x-ais-classified=unclassified&listeningSessionID=0CD_382_71__38c871ffc98aec765e17486bf1432ffad1ed0f23
# Reusing existing connection to stitcher.simplecastaudio.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 21652168 (21M) [audio/mpeg]
# Saving to: ‘podcast.mp3’
#
# podcast.mp3         100%[===================>]  20.65M  16.4MB/s    in 1.3s
#
# 2023-03-13 17:19:03 (16.4 MB/s) - ‘podcast.mp3’ saved [21652168/21652168]

# %%
result = model.transcribe('podcast.mp3')

# %%
from whisper.utils import write_vtt

# %%
with open('sub.vtt', "w") as txt:
  write_vtt(result["segments"], file=txt)

# %%
with open('sub.vtt', "r") as txt:
 print('\n'.join(txt.readlines()))
# Out:
# WEBVTT
#
#
#
# 00:00.000 --> 00:02.840
#
# Oh, hey, it's your old Pop Dad.
#
#
#
# 00:02.840 --> 00:05.880
#
# Flippin' pancakes in a flannel robe, it's Allie Ward.
#
#
#
# 00:05.880 --> 00:07.800
#
# We're back with another episode of Smology's.
#
#
#
# 00:07.800 --> 00:08.800
#
# What is Smology's?
#
#
#
# 00:08.800 --> 00:10.760
#
# I'm so glad that you asked.
#
#
#
# 00:10.760 --> 00:15.160
#
# So we took full Allogy's episodes and then we sliced and diced them up to make these
#
#
#
# 00:15.160 --> 00:20.060
#
# bite-sized classroom-friendly edits of our deep dive classics.
#
#
#
# 00:20.060 --> 00:23.800
#
# So we're about to fill your plates with a bunch of food facts this episode.
#
#
#
# 00:23.800 --> 00:26.960
#
# But first, let's feast on this, my thank yous.
#
#
#
# 00:26.960 --> 00:30.840
#
# Thank you to everyone supporting on Patreon, as little as 25 cents an episode gets you
#
#
#
# 00:30.840 --> 00:31.840
#
# into that club.
#
#
#
# 00:31.840 --> 00:34.200
#
# And then you can submit questions for the ologists.
#
#
#
# 00:34.200 --> 00:39.360
#
# Thank you to everyone who clothes your bodies in ologiesmerch.com items.
#
#
#
# 00:39.360 --> 00:41.400
#
# And thank you for rating and subscribing.
#
#
#
# 00:41.400 --> 00:43.500
#
# That keeps this podcast up in the charts.
#
#
#
# 00:43.500 --> 00:45.360
#
# So if you leave a review, I read it.
#
#
#
# 00:45.360 --> 00:46.840
#
# I'm creeped like that.
#
#
#
# 00:46.840 --> 00:50.480
#
# And this week, thank you to Heather Albrecht, who left a review that said that they had
#
#
#
# 00:50.480 --> 00:55.480
#
# a moment of deep relief and gratitude when their baby, quote, in the throes of a fantastic
#
#
#
# 00:55.480 --> 01:01.140
#
# lunchtime tantrum, stopped crying and smiled as the Allogies theme song came on.
#
#
#
# 01:01.140 --> 01:05.800
#
# And I hope they like the Smology theme song and learning about oysters and squash, Heather.
#
#
#
# 01:05.800 --> 01:06.800
#
# Thank you for that.
#
#
#
# 01:06.800 --> 01:07.800
#
# OK, let's go.
#
#
#
# 01:07.800 --> 01:11.280
#
# So food anthropology, it's the study of how we eat.
#
#
#
# 01:11.280 --> 01:14.160
#
# And this week's guest is a food historian of sorts.
#
#
#
# 01:14.160 --> 01:18.200
#
# I met her over a decade ago while we were both staff writers at the LA Times.
#
#
#
# 01:18.200 --> 01:20.560
#
# And she covered food, naturally.
#
#
#
# 01:20.560 --> 01:26.540
#
# And she moved up the ranks to be the LA Weekly Food Editor and the KCET Food Editor before
#
#
#
# 01:26.540 --> 01:31.080
#
# she jumped into the podcast realm with this truly amazing food history podcast called
#
#
#
# 01:31.080 --> 01:35.160
#
# Smart Mouth, where she invites a guest to talk about the history of their favorite foods.
#
#
#
# 01:35.160 --> 01:42.640
#
# She's also written for Gawker Media and Serious Eats and TasteMade and just launched HowToEatLA.com.
#
#
#
# 01:42.640 --> 01:46.480
#
# And for anyone who lives in LA and has a mouth, that is a great site.
#
#
#
# 01:46.480 --> 01:48.040
#
# We'll link that in the show notes.
#
#
#
# 01:48.040 --> 01:49.040
#
# It's awesome.
#
#
#
# 01:49.040 --> 01:53.840
#
# So pop that top button in your trousers and tuck a napkin into your collar and get ready
#
#
#
# 01:53.840 --> 02:00.680
#
# for a buffet of information with Smart Mouth podcast host, editor of HowToEatLA.com and
#
#
#
# 02:00.680 --> 02:21.880
#
# food anthropologist, Catherine Spires.
#
#
#
# 02:21.880 --> 02:23.520
#
# Now let's talk about feasts.
#
#
#
# 02:23.520 --> 02:24.520
#
# Yes.
#
#
#
# 02:24.520 --> 02:25.520
#
# Let's talk about winter feasts.
#
#
#
# 02:25.520 --> 02:26.520
#
# Yes.
#
#
#
# 02:26.520 --> 02:32.920
#
# So why do you think from an anthropological point of view, we just want to hunker down
#
#
#
# 02:32.920 --> 02:40.000
#
# and just get a little rolly polly and have insulin comas in the winter?
#
#
#
# 02:40.000 --> 02:42.480
#
# Because we need the warmth from the calories.
#
#
#
# 02:42.480 --> 02:45.800
#
# And also it's boring because it's dark out.
#
#
#
# 02:45.800 --> 02:46.800
#
# Okay.
#
#
#
# 02:46.800 --> 02:47.800
#
# I'm bored.
#
#
#
# 02:47.800 --> 02:48.800
#
# Let's eat.
#
#
#
# 02:48.800 --> 02:49.800
#
# Yeah, exactly.
#
#
#
# 02:49.800 --> 02:53.440
#
# Like you want to eat and also you don't mind sleeping more.
#
#
#
# 02:53.440 --> 02:54.960
#
# We are bears, essentially.
#
#
#
# 02:54.960 --> 02:56.600
#
# Like we follow the bear lifestyle.
#
#
#
# 02:56.600 --> 03:01.880
#
# I mean, in the wild, our lipid stores are our bank accounts.
#
#
#
# 03:01.880 --> 03:02.880
#
# Yes.
#
#
#
# 03:02.880 --> 03:03.880
#
# Yeah.
#
#
#
# 03:03.880 --> 03:09.880
#
# I feel like when you see a badonkadonk bear, that bear is wealthy with fats.
#
#
#
# 03:09.880 --> 03:10.880
#
# Yes.
#
#
#
# 03:10.880 --> 03:14.520
#
# Which I suppose in the winter, we do need that.
#
#
#
# 03:14.520 --> 03:19.840
#
# When it comes to feasting in the winter, what was it like historically in any part of the
#
#
#
# 03:19.840 --> 03:21.760
#
# world you can think of?
#
#
#
# 03:21.760 --> 03:25.680
#
# Did we eat things we'd put in the root cellar in the summer or did we just find what was
#
#
#
# 03:25.680 --> 03:26.680
#
# available?
#
#
#
# 03:26.680 --> 03:27.680
#
# Where is the food coming from?
#
#
#
# 03:27.680 --> 03:31.400
#
# So your point about lipids being wealth actually applies to humanity too.
#
#
#
# 03:31.400 --> 03:37.040
#
# Like if you're having a feast in the winter, that means you can afford sugar and salt.
#
#
#
# 03:37.040 --> 03:39.720
#
# You are out of control wealthy.
#
#
#
# 03:39.720 --> 03:40.720
#
# Right.
#
#
#
# 03:40.720 --> 03:41.720
#
# Yeah.
#
#
#
# 03:41.720 --> 03:45.160
#
# So a lot of it, there's different kinds of feasting.
#
#
#
# 03:45.160 --> 03:49.980
#
# And we like to think of feasting as being like celebrations and like we're all in this
#
#
#
# 03:49.980 --> 03:52.560
#
# together and we're all celebrating and we're all having a good time.
#
#
#
# 03:52.560 --> 03:56.600
#
# But humans being what they are, historically a lot of feasts are an opportunity to show
#
#
#
# 03:56.600 --> 03:58.920
#
# off basically to stunt on your neighbors.
#
#
#
# 03:58.920 --> 03:59.920
#
# No.
#
#
#
# 03:59.920 --> 04:03.240
#
# And part of it could be as simple, depending on like the era that you're in and the place
#
#
#
# 04:03.240 --> 04:04.240
#
# that you live.
#
#
#
# 04:04.240 --> 04:07.000
#
# Sometimes it is as simple as being like, oh, I'm sorry.
#
#
#
# 04:07.000 --> 04:09.040
#
# You hadn't seen this fruit in six months.
#
#
#
# 04:09.040 --> 04:10.040
#
# Yeah, I've got it.
#
#
#
# 04:10.040 --> 04:11.040
#
# Whatever.
#
#
#
# 04:11.040 --> 04:12.040
#
# Oh my God.
#
#
#
# 04:12.040 --> 04:15.360
#
# Yeah, it's preserved, but I've still got it and you don't because it means like the, again,
#
#
#
# 04:15.360 --> 04:16.600
#
# you have the ingredients to do it.
#
#
#
# 04:16.600 --> 04:22.560
#
# You have the time when you're not out just trying to do subsistence farming to like preserve
#
#
#
# 04:22.560 --> 04:23.560
#
# things for later.
#
#
#
# 04:23.560 --> 04:25.060
#
# You have time to plan ahead.
#
#
#
# 04:25.060 --> 04:28.560
#
# Being able to plan ahead is also another rich person thing still to this day.
#
#
#
# 04:28.560 --> 04:31.520
#
# So did peasants not have winter feasts?
#
#
#
# 04:31.520 --> 04:32.800
#
# Let them eat cake.
#
#
#
# 04:32.800 --> 04:33.800
#
# Harder to.
#
#
#
# 04:33.800 --> 04:38.420
#
# And that's so that's part of the the mixture of like celebration and stunting on people
#
#
#
# 04:38.420 --> 04:45.440
#
# is that lots of times like the Lord of the Manor would throw a feast for the serfs.
#
#
#
# 04:45.440 --> 04:50.480
#
# And that was partly to be like, thank you, but also to be like, see how great I am to
#
#
#
# 04:50.480 --> 04:51.480
#
# you.
#
#
#
# 04:51.480 --> 04:52.480
#
# Oh, no.
#
#
#
# 04:52.480 --> 04:57.680
#
# Like don't don't affect to another farm because I've got the best feasts in town.
#
#
#
# 04:57.680 --> 04:59.220
#
# Bribing someone with baked goods.
#
#
#
# 04:59.220 --> 05:01.320
#
# It is a tale as old as time.
#
#
#
# 05:01.320 --> 05:02.480
#
# But how do we know?
#
#
#
# 05:02.480 --> 05:06.920
#
# It's interesting that the oldest evidence of feast that we have actually comes from
#
#
#
# 05:06.920 --> 05:09.960
#
# art rather than archaeology.
#
#
#
# 05:09.960 --> 05:14.880
#
# Oh, because I guess it's not like chicken bones in a casserole dish wouldn't preserve,
#
#
#
# 05:14.880 --> 05:15.880
#
# I guess.
#
#
#
# 05:15.880 --> 05:17.480
#
# Yeah, that could well be it.
#
#
#
# 05:17.480 --> 05:20.360
#
# Feasts often come from offerings to the gods as well.
#
#
#
# 05:20.360 --> 05:22.160
#
# It's like a party, but also an offering.
#
#
#
# 05:22.160 --> 05:28.400
#
# So they have like basically like pottery shards from like ancient China and Sumeria, which
#
#
#
# 05:28.400 --> 05:29.400
#
# is Iraq.
#
#
#
# 05:29.400 --> 05:34.800
#
# OK, so when what is what's the history of American holiday season feasting?
#
#
#
# 05:34.800 --> 05:39.320
#
# So where do you even start with this one?
#
#
#
# 05:39.320 --> 05:44.240
#
# First prefacing by the fact that we are talking about like Northwestern European traditions
#
#
#
# 05:44.240 --> 05:47.560
#
# coming over to America and starting in New England and spreading out from there.
#
#
#
# 05:47.560 --> 05:49.560
#
# That's probably a lot to unpack.
#
#
#
# 05:49.560 --> 05:51.080
#
# It is a lot to unpack.
#
#
#
# 05:51.080 --> 05:53.120
#
# And I wanted to do a little digging here.
#
#
#
# 05:53.120 --> 05:58.000
#
# One publication Indian Country Today had a great article and interview from a few years
#
#
#
# 05:58.000 --> 06:00.360
#
# back with Ramona Peters.
#
#
#
# 06:00.360 --> 06:05.160
#
# She's the Mashpee Wampanoag Tribes Tribal Historic Preservation Officer.
#
#
#
# 06:05.160 --> 06:11.960
#
# Now she said in regard to the famed 1621 inaugural Thanksgiving feast, she said the following
#
#
#
# 06:11.960 --> 06:12.960
#
# thing.
#
#
#
# 06:12.960 --> 06:13.960
#
# It was made up.
#
#
#
# 06:13.960 --> 06:17.560
#
# It was a young Lincoln who used the theme of pilgrims and Indians eating happily together
#
#
#
# 06:17.560 --> 06:22.840
#
# because he was trying to calm things down during the Civil War when people were divided.
#
#
#
# 06:22.840 --> 06:26.240
#
# It was like a nice unity story for public relations.
#
#
#
# 06:26.240 --> 06:29.400
#
# She said it's kind of genius in a way to get people to sit down and eat dinner together
#
#
#
# 06:29.400 --> 06:32.360
#
# because families were divided during the Civil War.
#
#
#
# 06:32.360 --> 06:35.220
#
# Ramona Peters was asked if she'll celebrate Thanksgiving anyway.
#
#
#
# 06:35.220 --> 06:40.120
#
# And she said, as a concept, a heartfelt Thanksgiving is very important to me as a person.
#
#
#
# 06:40.120 --> 06:42.040
#
# It's important that we give thanks.
#
#
#
# 06:42.040 --> 06:44.160
#
# For me, it's a state of being.
#
#
#
# 06:44.160 --> 06:47.240
#
# So that was a great article in Indian Country Today.
#
#
#
# 06:47.240 --> 06:50.240
#
# And there are other wonderful first person experiences.
#
#
#
# 06:50.240 --> 06:55.040
#
# Smithsonian, AmericanIndian.si.edu has some great articles as well.
#
#
#
# 06:55.040 --> 06:57.000
#
# But getting back to the food history.
#
#
#
# 06:57.000 --> 06:58.600
#
# So much meat.
#
#
#
# 06:58.600 --> 07:01.680
#
# Basically any kind of meat you could get, which was turkey, wild turkeys, which don't
#
#
#
# 07:01.680 --> 07:05.720
#
# look like the turkeys that we eat now, but it is the same animal and then venison and
#
#
#
# 07:05.720 --> 07:10.100
#
# seafood, which actually even to this day, seafood is a bigger part of the New England
#
#
#
# 07:10.100 --> 07:12.480
#
# Thanksgiving menu than it is anywhere else.
#
#
#
# 07:12.480 --> 07:13.480
#
# What?
#
#
#
# 07:13.480 --> 07:14.480
#
# Seafood?
#
#
#
# 07:14.480 --> 07:16.320
#
# Yeah, oysters and mussels are a big part of it.
#
#
#
# 07:16.320 --> 07:23.040
#
# So you're saying the first Thanksgiving's more meat, deer, turkeys, oysters, mussels.
#
#
#
# 07:23.040 --> 07:24.560
#
# And all the other poultries they could find.
#
#
#
# 07:24.560 --> 07:27.440
#
# Just everyone's they could find and shoot before they flew away.
#
#
#
# 07:27.440 --> 07:30.360
#
# They were like, yes, let's do some of this.
#
#
#
# 07:30.360 --> 07:36.100
#
# And what I think you can like sort of see how things change for people and like the
#
#
#
# 07:36.100 --> 07:41.040
#
# changing Thanksgiving menu, because for one thing, again, they didn't have a lot of herbs
#
#
#
# 07:41.040 --> 07:44.440
#
# and spices back then because those were wildly expensive.
#
#
#
# 07:44.440 --> 07:47.000
#
# They hadn't figured out how to use the new ones.
#
#
#
# 07:47.000 --> 07:51.100
#
# They hadn't like figured out how to grow the ones they brought from Europe.
#
#
#
# 07:51.100 --> 07:54.000
#
# Roasted flesh just tastes good on its own.
#
#
#
# 07:54.000 --> 07:57.640
#
# You don't have to do a lot with it the way that you do have to do with side dishes that
#
#
#
# 07:57.640 --> 07:59.560
#
# need a lot of different ingredients.
#
#
#
# 07:59.560 --> 08:01.620
#
# And again, it's survival food.
#
#
#
# 08:01.620 --> 08:07.840
#
# They had an abundance of meat, which is rare, but they weren't like coming up with new recipes.
#
#
#
# 08:07.840 --> 08:08.840
#
# Right.
#
#
#
# 08:08.840 --> 08:10.440
#
# They were like, it's not alive.
#
#
#
# 08:10.440 --> 08:12.440
#
# It's not wiggling.
#
#
#
# 08:12.440 --> 08:13.440
#
# Let's eat it.
#
#
#
# 08:13.440 --> 08:14.440
#
# Exactly.
#
#
#
# 08:14.440 --> 08:19.240
#
# The idea of having like flavored food, I think as northern Europeans started traveling the
#
#
#
# 08:19.240 --> 08:22.200
#
# globe, they were like, this tastes good taste.
#
#
#
# 08:22.200 --> 08:25.400
#
# Is that even a word?
#
#
#
# 08:25.400 --> 08:32.120
#
# And now when did, let's say like the Thanksgiving feast become a widespread American phenomenon?
#
#
#
# 08:32.120 --> 08:38.880
#
# And what's changed just in the last at least decade of us like getting hip to the fact
#
#
#
# 08:38.880 --> 08:41.400
#
# that it's all apocryphal?
#
#
#
# 08:41.400 --> 08:50.120
#
# Okay, so Thanksgiving for a long time was really only celebrated in New England.
#
#
#
# 08:50.120 --> 08:54.160
#
# Oh, basically the people whose grandparents were there.
#
#
#
# 08:54.160 --> 08:57.800
#
# Oh my God, it's like Woodstock or something.
#
#
#
# 08:57.800 --> 08:59.000
#
# Exactly.
#
#
#
# 08:59.000 --> 09:03.680
#
# So I really think it was until around probably like just after the Civil War that the rest
#
#
#
# 09:03.680 --> 09:06.120
#
# of the country got into the idea.
#
#
#
# 09:06.120 --> 09:07.120
#
# Okay.
#
#
#
# 09:07.120 --> 09:11.640
#
# And you can still to this day see regional differences in what people consider necessary
#
#
#
# 09:11.640 --> 09:12.960
#
# for a Thanksgiving dinner.
#
#
#
# 09:12.960 --> 09:16.320
#
# Oh my God, like is this going to be all about green bean casserole?
#
#
#
# 09:16.320 --> 09:19.320
#
# It's largely about green bean casserole.
#
#
#
# 09:19.320 --> 09:25.320
#
# There was a phenomenon that started around 1900 and lasted like probably until the 80s
#
#
#
# 09:25.320 --> 09:30.720
#
# and that is food companies, the ones that sell packaged food, processed food, writing
#
#
#
# 09:30.720 --> 09:34.880
#
# their own recipes in house and sending them out both as recipe booklets, but also sending
#
#
#
# 09:34.880 --> 09:37.600
#
# them to newspapers to be published in the newspapers.
#
#
#
# 09:37.600 --> 09:39.080
#
# Oh, yeah.
#
#
#
# 09:39.080 --> 09:43.720
#
# And the recipes could be good, bad and different, but it was mainly about selling the products
#
#
#
# 09:43.720 --> 09:45.200
#
# that these companies made.
#
#
#
# 09:45.200 --> 09:52.560
#
# So green bean casserole was invented by this food scientist who worked for a food company
#
#
#
# 09:52.560 --> 09:55.560
#
# as a way to use cream of mushroom soup.
#
#
#
# 09:55.560 --> 10:00.640
#
# So a big feast meal is made with love and propaganda.
#
#
#
# 10:00.640 --> 10:02.520
#
# Now what else is on your holiday table?
#
#
#
# 10:02.520 --> 10:04.760
#
# What are some other dishes that are pretty regional?
#
#
#
# 10:04.760 --> 10:08.720
#
# Are some people like where a canned smooth cranberry sauce?
#
#
#
# 10:08.720 --> 10:13.640
#
# Estate and others are like chunky and others are like we make it on the stove.
#
#
#
# 10:13.640 --> 10:17.600
#
# That one I think isn't regional necessarily.
#
#
#
# 10:17.600 --> 10:21.360
#
# What is regional is sweet potato casserole.
#
#
#
# 10:21.360 --> 10:22.560
#
# That's another southern one.
#
#
#
# 10:22.560 --> 10:26.160
#
# That is another company created recipe.
#
#
#
# 10:26.160 --> 10:27.160
#
# It was a marshmallow company.
#
#
#
# 10:27.160 --> 10:31.960
#
# I think it was called Angelus and they hired a woman who wrote a cooking magazine in the
#
#
#
# 10:31.960 --> 10:36.520
#
# 1920s to find out how to convince people to use marshmallows more.
#
#
#
# 10:36.520 --> 10:37.520
#
# Oh my god.
#
#
#
# 10:37.520 --> 10:39.200
#
# That was one of her inventions.
#
#
#
# 10:39.200 --> 10:43.200
#
# Did feasting like this really take off?
#
#
#
# 10:43.200 --> 10:47.960
#
# You said after the Civil War but after the night like the turn of the century, 1900s
#
#
#
# 10:47.960 --> 10:51.120
#
# like industrial era, when did we see an explosion in this kind of eating?
#
#
#
# 10:51.120 --> 10:57.880
#
# So it wasn't until the 1930s that petitions to make it a national holiday really picked
#
#
#
# 10:57.880 --> 10:58.880
#
# up.
#
#
#
# 10:58.880 --> 11:04.240
#
# So it was Franklin Roosevelt who had to make the decision of which day to place it.
#
#
#
# 11:04.240 --> 11:05.320
#
# How did they decide?
#
#
#
# 11:05.320 --> 11:07.520
#
# It was such a huge fight.
#
#
#
# 11:07.520 --> 11:10.400
#
# In one year there were two Thanksgivings.
#
#
#
# 11:10.400 --> 11:11.400
#
# Stop it.
#
#
#
# 11:11.400 --> 11:13.040
#
# Yeah because they couldn't decide.
#
#
#
# 11:13.040 --> 11:21.200
#
# People had said fourth Thursday in November and then the Republican Congress got together,
#
#
#
# 11:21.200 --> 11:24.200
#
# Republican majority Congress got together with like the Business Leaders Association
#
#
#
# 11:24.200 --> 11:27.320
#
# of America or whatever it was and they're like no make it the third one because they
#
#
#
# 11:27.320 --> 11:31.320
#
# wanted people to be able to shop for Christmas and feel okay about it for longer.
#
#
#
# 11:31.320 --> 11:37.400
#
# But then Roosevelt's idea eventually won out but in the 1930s there was like a lot of madness
#
#
#
# 11:37.400 --> 11:40.640
#
# around where to place Thanksgiving.
#
#
#
# 11:40.640 --> 11:42.840
#
# What else has changed over the years?
#
#
#
# 11:42.840 --> 11:46.360
#
# And that's a difference too in like the way that Thanksgiving has evolved is that it used
#
#
#
# 11:46.360 --> 11:49.060
#
# to be like eating meat was the fancy thing.
#
#
#
# 11:49.060 --> 11:53.920
#
# But as America became more industrialized and wealthier you see the addition of ingredients
#
#
#
# 11:53.920 --> 11:56.160
#
# like every dairy product.
#
#
#
# 11:56.160 --> 11:57.760
#
# That's something that only rich people can do.
#
#
#
# 11:57.760 --> 11:59.840
#
# I never thought of it that way.
#
#
#
# 11:59.840 --> 12:03.760
#
# Yeah so you move away from meat being the special dish to like all the things that like
#
#
#
# 12:03.760 --> 12:07.880
#
# take time and energy or you have to buy that you can't make yourself and being like the
#
#
#
# 12:07.880 --> 12:09.000
#
# star of the show.
#
#
#
# 12:09.000 --> 12:14.080
#
# Why when we think of cartoon feasts do we see a pig with an apple in its mouth?
#
#
#
# 12:14.080 --> 12:16.280
#
# I think for maximum upsettingness.
#
#
#
# 12:16.280 --> 12:18.040
#
# Okay I always wondered what that was.
#
#
#
# 12:18.040 --> 12:19.480
#
# It was always like oh this means we're feasting.
#
#
#
# 12:19.480 --> 12:20.760
#
# You're like get that thing out of there.
#
#
#
# 12:20.760 --> 12:26.320
#
# Well it is that sort of like English thing which I think in our heads were like animal
#
#
#
# 12:26.320 --> 12:31.320
#
# presented whole on the table and if we're talking about like a European cultural influence
#
#
#
# 12:31.320 --> 12:33.440
#
# like that's what we think of for fancy.
#
#
#
# 12:33.440 --> 12:38.960
#
# But if you think about Asian food, foods that are sort of family style obviously lend themselves
#
#
#
# 12:38.960 --> 12:40.680
#
# more to feasting.
#
#
#
# 12:40.680 --> 12:41.680
#
# That's a good point.
#
#
#
# 12:41.680 --> 12:44.160
#
# Which I think might be part of the reason why so many people who don't celebrate Christmas
#
#
#
# 12:44.160 --> 12:45.720
#
# now do Chinese food.
#
#
#
# 12:45.720 --> 12:50.760
#
# Because you still got that same vibe and it's even more communal because everyone's like
#
#
#
# 12:50.760 --> 12:53.800
#
# sharing from the same dishes which we tend to do on Thanksgiving.
#
#
#
# 12:53.800 --> 12:54.800
#
# Same idea.
#
#
#
# 12:54.800 --> 12:57.880
#
# Because the idea of having a lazy Susan and a bunch of dishes at a round table where you
#
#
#
# 12:57.880 --> 13:00.120
#
# can see everyone.
#
#
#
# 13:00.120 --> 13:06.920
#
# Like that lends itself to not only the eating experience but also the sharing of plates.
#
#
#
# 13:06.920 --> 13:07.920
#
# Absolutely.
#
#
#
# 13:07.920 --> 13:11.320
#
# Because I feel like in Western culture we don't really have that.
#
#
#
# 13:11.320 --> 13:15.560
#
# But before we spin ourselves into the questions that you submitted patrons let's take a quick
#
#
#
# 13:15.560 --> 13:18.440
#
# break to raise some money for a worthy cause.
#
#
#
# 13:18.440 --> 13:23.280
#
# And Catherine just launched that new website howtoeatla.com and so in her honor we're donating
#
#
#
# 13:23.280 --> 13:29.200
#
# to the LA regional food bank because one in five people in Los Angeles County experiences
#
#
#
# 13:29.200 --> 13:33.840
#
# food insecurity and the food bank has been fighting hunger since 1973.
#
#
#
# 13:33.840 --> 13:40.160
#
# That's 25 bucks provides the equivalent of 100 meals for kids seniors and folks who need
#
#
#
# 13:40.160 --> 13:41.280
#
# something to eat.
#
#
#
# 13:41.280 --> 13:48.880
#
# So learn more at lafoodbank.org and thanks to these sponsors for helping fund that donation.
#
#
#
# 13:48.880 --> 13:50.000
#
# Okay let's dive in.
#
#
#
# 13:50.000 --> 13:52.480
#
# Let's digest your questions.
#
#
#
# 13:52.480 --> 13:56.360
#
# Vincent wants to know why do traditions vary so much from country to country about what
#
#
#
# 13:56.360 --> 14:00.600
#
# foods are feast foods and are there any feast foods that are just seen all over the world
#
#
#
# 14:00.600 --> 14:02.960
#
# no matter what the local culture is?
#
#
#
# 14:02.960 --> 14:09.000
#
# So it's the issue of abundance which is going to change based on the flora and fauna of
#
#
#
# 14:09.000 --> 14:11.200
#
# wherever it is that you are.
#
#
#
# 14:11.200 --> 14:14.760
#
# Starches traditionally well just the plain starches like plain rice plain noodles are
#
#
#
# 14:14.760 --> 14:18.440
#
# never going to be a feast food because those are the easy things to get.
#
#
#
# 14:18.440 --> 14:23.960
#
# It's when you start being like I've got this potato but I also have two pounds of butter.
#
#
#
# 14:23.960 --> 14:25.520
#
# That's what makes something a feast food.
#
#
#
# 14:25.520 --> 14:27.400
#
# So it is it's items that are scarce.
#
#
#
# 14:27.400 --> 14:30.680
#
# So fruit for instance is considered very special.
#
#
#
# 14:30.680 --> 14:33.440
#
# Meat dairy product is considered very special.
#
#
#
# 14:33.440 --> 14:38.120
#
# Meat used to be considered very special but because of industrialization it's not as much
#
#
#
# 14:38.120 --> 14:39.880
#
# anymore.
#
#
#
# 14:39.880 --> 14:46.640
#
# So these things will also change with just as the culture changes so do like the considerations
#
#
#
# 14:46.640 --> 14:48.760
#
# like what is special or fancy.
#
#
#
# 14:48.760 --> 14:49.760
#
# So it's the rarity.
#
#
#
# 14:49.760 --> 14:51.500
#
# Yeah always the rarity.
#
#
#
# 14:51.500 --> 14:58.000
#
# We want and we appreciate what we can't usually have and what exemplifies that more than social
#
#
#
# 14:58.000 --> 14:59.040
#
# media?
#
#
#
# 14:59.040 --> 15:01.800
#
# And now Sarah wants to know how his Instagram changed food.
#
#
#
# 15:01.800 --> 15:02.800
#
# Is it prettier now?
#
#
#
# 15:02.800 --> 15:03.800
#
# Yes.
#
#
#
# 15:03.800 --> 15:09.960
#
# Oh it is absolutely prettier and restaurants at the beginning would pretend like they didn't
#
#
#
# 15:09.960 --> 15:11.520
#
# care.
#
#
#
# 15:11.520 --> 15:13.240
#
# You actually can see it.
#
#
#
# 15:13.240 --> 15:17.220
#
# I think for me the place where it's more obvious is restaurant design.
#
#
#
# 15:17.220 --> 15:23.280
#
# Like restaurants have bigger windows now and they have planar table tops and walls with
#
#
#
# 15:23.280 --> 15:25.000
#
# pops of color.
#
#
#
# 15:25.000 --> 15:27.360
#
# So they're thinking about what will be a good background.
#
#
#
# 15:27.360 --> 15:33.680
#
# Yeah and then you'll also see on the plates and on more casual places on the like piece
#
#
#
# 15:33.680 --> 15:37.320
#
# of tissue paper that they put on the plate will now be stamped with the logo and the
#
#
#
# 15:37.320 --> 15:39.300
#
# name of the restaurant on it.
#
#
#
# 15:39.300 --> 15:40.300
#
# Name plates.
#
#
#
# 15:40.300 --> 15:41.600
#
# They're just a sign of the times.
#
#
#
# 15:41.600 --> 15:46.720
#
# Oh and speaking of timing, Nicole Sauce wants to know why have so many holidays come to
#
#
#
# 15:46.720 --> 15:48.720
#
# revolve around foods and feasts?
#
#
#
# 15:48.720 --> 15:51.080
#
# Thanksgiving, Passover, Hanukkah, Christmas.
#
#
#
# 15:51.080 --> 15:53.520
#
# So in a sense why do the holidays?
#
#
#
# 15:53.520 --> 15:54.520
#
# Is it gathering?
#
#
#
# 15:54.520 --> 15:55.520
#
# Is it winter?
#
#
#
# 15:55.520 --> 16:02.560
#
# Yeah it's gathering, it's community but it's also we saved up for this which was a lot
#
#
#
# 16:02.560 --> 16:06.800
#
# more obvious pre-industrialization where it's like we have one pig and we're not going to
#
#
#
# 16:06.800 --> 16:08.360
#
# eat it until this holiday.
#
#
#
# 16:08.360 --> 16:11.840
#
# Marissa Buru wants to know why do some cultures fixate on food more than others?
#
#
#
# 16:11.840 --> 16:16.340
#
# Like in France lunches are two hours long and food is very important but the U.S. food
#
#
#
# 16:16.340 --> 16:19.200
#
# breaks are like not even taken seriously.
#
#
#
# 16:19.200 --> 16:22.800
#
# So I actually think this totally goes back to what we were talking about earlier about
#
#
#
# 16:22.800 --> 16:26.240
#
# feast days and how Americans can't just like relax.
#
#
#
# 16:26.240 --> 16:30.520
#
# We are totally Calvinistic in our society even if no one even knows what that means
#
#
#
# 16:30.520 --> 16:31.520
#
# anymore.
#
#
#
# 16:31.520 --> 16:34.480
#
# Here let me read the dictionary for us both.
#
#
#
# 16:34.480 --> 16:38.960
#
# Calvinistic marked by strong emphasis on the depravity of humankind.
#
#
#
# 16:38.960 --> 16:40.200
#
# So in other words?
#
#
#
# 16:40.200 --> 16:44.400
#
# We do not believe in having a nice time.
#
#
#
# 16:44.400 --> 16:49.820
#
# France is like you only have one life enjoy it eat a lunch.
#
#
#
# 16:49.820 --> 16:54.960
#
# And Calvinism side note was the brainchild of a Protestant thinker John Calvin who was
#
#
#
# 16:54.960 --> 17:00.840
#
# a theologian which is someone who studies the nature of God or religious beliefs which
#
#
#
# 17:00.840 --> 17:01.840
#
# reminds me.
#
#
#
# 17:01.840 --> 17:03.480
#
# Okay you are a religious studies major.
#
#
#
# 17:03.480 --> 17:09.560
#
# Paula Herrera wants to know is the Last Supper considered a historical feast or just theological?
#
#
#
# 17:09.560 --> 17:13.160
#
# Like assuming it did actually happen when they have eaten anything other than bread
#
#
#
# 17:13.160 --> 17:14.160
#
# and wine.
#
#
#
# 17:14.160 --> 17:20.320
#
# Oh God this is actually so funny because I happen to know that Da Vinci's The Last Supper
#
#
#
# 17:20.320 --> 17:22.240
#
# painted in the 1490s.
#
#
#
# 17:22.240 --> 17:26.980
#
# It's really muddy now by like years of existing and also bad restorations but the food items
#
#
#
# 17:26.980 --> 17:30.960
#
# depicted on the table in his painting of The Last Supper are oranges and eels.
#
#
#
# 17:30.960 --> 17:33.400
#
# He's the serve the eels here boy.
#
#
#
# 17:33.400 --> 17:39.160
#
# Not sure but I did dig up that one of the reasons the meal depicted was pescatarian
#
#
#
# 17:39.160 --> 17:44.840
#
# could have been because Da Vinci himself was a vegetarian because he loved animals so much.
#
#
#
# 17:44.840 --> 17:49.680
#
# So Leonardo Da Vinci the first maybe vegan influencer.
#
#
#
# 17:49.680 --> 17:51.960
#
# I find this cute and inspiring.
#
#
#
# 17:51.960 --> 17:56.440
#
# Tina Roudio wants to know who was the first person to deep fry a whole turkey.
#
#
#
# 17:56.440 --> 17:59.320
#
# I'm going to look into it.
#
#
#
# 17:59.320 --> 18:01.280
#
# I'm pretty sure that's Southern.
#
#
#
# 18:01.280 --> 18:06.720
#
# So story goes that in the 1930s a Cajun chef witnessed a deep fried turkey and was like
#
#
#
# 18:06.720 --> 18:09.560
#
# yep that's going to happen more I'm going to start that.
#
#
#
# 18:09.560 --> 18:12.600
#
# Don't undertake it lightheartedly and this is I'm going to say something and everyone
#
#
#
# 18:12.600 --> 18:15.980
#
# listening is going to be like yeah duh except for that people don't think about it.
#
#
#
# 18:15.980 --> 18:16.980
#
# Don't do it indoors.
#
#
#
# 18:16.980 --> 18:18.400
#
# Oh God no.
#
#
#
# 18:18.400 --> 18:23.640
#
# It has to be done outside and like have your fire extinguisher ready.
#
#
#
# 18:23.640 --> 18:25.560
#
# Yeah things can go very very wrong.
#
#
#
# 18:25.560 --> 18:30.400
#
# Apparently it's delicious clearly that's why people keep doing it but don't hurt yourself.
#
#
#
# 18:30.400 --> 18:31.400
#
# It's not worth it.
#
#
#
# 18:31.400 --> 18:32.960
#
# It's not.
#
#
#
# 18:32.960 --> 18:37.720
#
# So play it safe because it might save your life unless you're a turkey.
#
#
#
# 18:37.720 --> 18:41.640
#
# Actually speaking of sparing the birds Todd McLaren wants to know what are some popular
#
#
#
# 18:41.640 --> 18:46.280
#
# vegetarian feast main dishes other than the ones that mimic meats like tofurkey.
#
#
#
# 18:46.280 --> 18:50.720
#
# Can we what about like us like a stuffed portobello or like a.
#
#
#
# 18:50.720 --> 18:56.760
#
# Yeah I've heard some vegetarians joke about how mushrooms are the meat for vegetarians.
#
#
#
# 18:56.760 --> 19:00.280
#
# I think mushrooms are really delicious and you can I think stuffed portobello is a really
#
#
#
# 19:00.280 --> 19:01.280
#
# good idea.
#
#
#
# 19:01.280 --> 19:09.120
#
# Well sometimes it just has to do with the seasoning that you put on tofu or tempeh that
#
#
#
# 19:09.120 --> 19:11.320
#
# makes it delicious.
#
#
#
# 19:11.320 --> 19:17.240
#
# The reason why tofu was used as a meat substitute was like a Chinese Buddhist thing where they
#
#
#
# 19:17.240 --> 19:21.600
#
# would just they would actually like form the tofu into the shape of the animal and season
#
#
#
# 19:21.600 --> 19:25.060
#
# it with the seasonings that you would use for that animal.
#
#
#
# 19:25.060 --> 19:28.860
#
# So this is true as Buddhism spread from China to Japan.
#
#
#
# 19:28.860 --> 19:35.880
#
# So did tofu and the Japanese label of Shojin Ryote arrives in Japan via the founder of
#
#
#
# 19:35.880 --> 19:41.640
#
# Zen Buddhism a monk and many Shojin dishes mimic meat and are called things like mock
#
#
#
# 19:41.640 --> 19:47.400
#
# goose which doesn't have quite the same ring as a tofurkey which is a loaf of roasted bean
#
#
#
# 19:47.400 --> 19:52.520
#
# curd that has spared many a bird during its 42 years on the planet.
#
#
#
# 19:52.520 --> 19:54.040
#
# What do you love about your job the most.
#
#
#
# 19:54.040 --> 19:57.760
#
# What's the best thing about being a food anthropologist.
#
#
#
# 19:57.760 --> 20:05.240
#
# I like finding out new stuff all the time and I think it's been such a way in for me
#
#
#
# 20:05.240 --> 20:10.160
#
# to understand more about the way that the world works which is really cool and to it's
#
#
#
# 20:10.160 --> 20:13.760
#
# so easy for us to be knee jerk and be like why did that person do that thing.
#
#
#
# 20:13.760 --> 20:17.200
#
# But if you know why you can empathize a little bit more to the point where actually I think
#
#
#
# 20:17.200 --> 20:22.440
#
# I'm too empathetic I can see other people's points of view constantly and it's exhaust.
#
#
#
# 20:22.440 --> 20:25.000
#
# It's a good problem to have.
#
#
#
# 20:25.000 --> 20:26.880
#
# It is.
#
#
#
# 20:26.880 --> 20:32.000
#
# So ask smart mouth people a heaping helping of questions because they love to spill the
#
#
#
# 20:32.000 --> 20:33.000
#
# beans.
#
#
#
# 20:33.000 --> 20:37.800
#
# Now once again Catherine Spires has a food history podcast called Smart Mouth.
#
#
#
# 20:37.800 --> 20:39.160
#
# It's truly excellent.
#
#
#
# 20:39.160 --> 20:41.760
#
# She also owns the podcast network Table Cakes.
#
#
#
# 20:41.760 --> 20:44.320
#
# So check out that array of shows.
#
#
#
# 20:44.320 --> 20:45.800
#
# She just launched how to eat L.A.
#
#
#
# 20:45.800 --> 20:50.200
#
# Dot com if you're an Angelino who needs to know what to eat here and a link to the L.A.
#
#
#
# 20:50.200 --> 20:55.160
#
# regional food bank is in the show notes and she is at Catherine Spires on Twitter Catherine
#
#
#
# 20:55.160 --> 20:57.040
#
# underscore spires on Instagram.
#
#
#
# 20:57.040 --> 21:01.040
#
# We are at all of these on Twitter and Instagram and I'm at Ali Ward on both.
#
#
#
# 21:01.040 --> 21:02.820
#
# And thank you new small guys for being here.
#
#
#
# 21:02.820 --> 21:04.720
#
# New episodes are out every other Sunday.
#
#
#
# 21:04.720 --> 21:10.780
#
# You can check the URL Ali Ward dot com slash small g's or the link the bio for 16 other
#
#
#
# 21:10.780 --> 21:13.920
#
# small g's episodes and counting for your holiday drives.
#
#
#
# 21:13.920 --> 21:17.840
#
# Thank you Mercedes Maitland and Jared Sleeper for working on those links to the original
#
#
#
# 21:17.840 --> 21:23.240
#
# full episode are available on Ali Ward dot com or in the show notes and a full list of
#
#
#
# 21:23.240 --> 21:26.320
#
# credits for this episode can be found in the show notes as well since we like to keep things
#
#
#
# 21:26.320 --> 21:27.600
#
# small around here.
#
#
#
# 21:27.600 --> 21:30.960
#
# And if you listen to the end you know I give you a piece of advice and this week it's just
#
#
#
# 21:30.960 --> 21:36.000
#
# that when you're shopping for holiday food and you have the option or ability to get
#
#
#
# 21:36.000 --> 21:38.400
#
# a second can of whipped cream get it.
#
#
#
# 21:38.400 --> 21:41.500
#
# No one ever turns down a second helping of whipped cream.
#
#
#
# 21:41.500 --> 21:42.720
#
# We all love it.
#
#
#
# 21:42.720 --> 21:47.400
#
# Also if you're not able to volunteer or to donate at all this holiday season to a soup
#
#
#
# 21:47.400 --> 21:49.840
#
# kitchen or food bank don't worry.
#
#
#
# 21:49.840 --> 21:55.300
#
# They need volunteers and donations all year round and help is always appreciated even
#
#
#
# 21:55.300 --> 21:57.720
#
# more so after the holiday cheer dies down.
#
#
#
# 21:57.720 --> 22:01.480
#
# And if you're getting your food from a food bank or from a soup kitchen there's absolutely
#
#
#
# 22:01.480 --> 22:04.740
#
# nothing wrong with that and that is what people are here for to help each other out.
#
#
#
# 22:04.740 --> 22:07.800
#
# So I hope that you have a big good dinner because you deserve it.
#
#
#
# 22:07.800 --> 22:09.800
#
# OK until next time small gites.
#
#
#
# 22:09.800 --> 22:32.520
#
# Bye bye.

# %%
import gradio as gr 
import whisper
from whisper.utils import write_vtt
import requests
import os

def inference(link):
  content = requests.get(link)
  podcast_url = re.findall("(?P<url>\;https?://[^\s]+)", content.text)[0].split(';')[1]
  print(podcast_url)
  

  download = requests.get(podcast_url)

  with open('podcast.mp3', 'wb') as f:
    f.write(download.content)

  result = model.transcribe('podcast.mp3')

  with open('sub.vtt', "w") as txt:
    write_vtt(result["segments"], file=txt)

  return (result['text'], 'sub.vtt')

  


title="why listen when you can read"
description="Get Podcast Transcript"
block = gr.Blocks()

with block:
    gr.HTML(
        """     <center> 
                <h1>Just read I guess</h1>
                <img src = 'https://static01.nyt.com/images/2019/04/06/smarter-living/sl-better-listener-guide-slide-5UDQ/sl-better-listener-guide-slide-5UDQ-jumbo.jpg' width = '50%'></img>
                </center>
        """
    )
    with gr.Group():
        with gr.Box():
          
          link = gr.Textbox(label="Google Podcasts Link")

          with gr.Row().style(mobile_collapse=False, equal_height=True): 
              btn = gr.Button("Get PodScript 🪄")
          
          text = gr.Textbox(
              label="listening", 
              placeholder="PodScript Output",
              lines=5)
          
          transcription = gr.File()     
       
          
          btn.click(inference, inputs=[link], outputs=[text,transcription])

block.launch(debug=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/gradio/layouts.py:75: UserWarning: mobile_collapse is no longer supported.
#   warnings.warn("mobile_collapse is no longer supported.")
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
# https://pdst.fm/e/stitcher.simplecastaudio.com/89060b63-e603-4297-b6e8-5a654e50244e/episodes/eac79fdd-3a3c-48b7-a6c2-b7258f72fdea/audio/128/default.mp3?aid=rss_feed&amp
